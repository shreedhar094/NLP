# %% [markdown]
# <a href="https://colab.research.google.com/github/shreedhar094/NLP/blob/main/EXp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
text = "Hi. I am Shreedhar"
output1 = sent_tokenize(text)
print(output1)
# Out:
# ['Hi.', 'I am Shreedhar']

# %%
# !pip install -U spacy

# %%
# !python -m download en_core_web_sm
# Out:
# /usr/bin/python3: No module named download

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
imput = "this is second session"
doc = nlp(imput)

# %%
for token in doc:
  print(token.text)
# Out:
# this
# is
# second
# session

# %%
for sent in doc.sents:
  print(sent.text)
# Out:
# this is second session
